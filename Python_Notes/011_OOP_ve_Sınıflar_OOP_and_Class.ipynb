# %%
emirhanName = "Emirhan"

# %%
emirhanAge = 90

# %%
emirhanGender = "Male"

# %%
cabikName = "Cabik"

# %%
cabikAge = 22

# %%
cabikGender = "Male"

# %%
class Person():  #Sınıflar genelde büyük harf ile tanımlanır. person diye yazılmaz Person olarak yazarız.
    pass

# %%
class Person():
    name = ""
    age = 0
    gender = ""

    #sınıfların içinde istediğimiz kadar fonk yazabiliriz ve sınıf içindeki fonksiyonlara method denir.

    def __init__(self,nameInput,ageInput,genderInput): #init -> initiliazer demek ilk oluşturmak değerini atamak demektir. def init tanımlarsak eğer bu sınıftan her obje oluşturduğumuzda her bir obje oluşturulurken buradaki fonk çalıştırılacak
        name = nameInput
        gender = genderInput
        age = ageInput

        #def __init__(self) - > self parametresi

# %%
myList = list()

# %%
type(myList)
# Out:
# list

# %%
emirhan = Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 emirhan = Person()
#
# TypeError: Person.__init__() missing 3 required positional arguments: 'nameInput', 'ageInput', and 'genderInput'

# %%
type(emirhan)

# %%
emirhan.name #.TAB kullanırsak bizimi class sınıfına verdiğimiz değer kadar çıkar.

# %%
emirhan.age = 22

# %%
emirhan.age

# %%
emirhan.name = "Emirhan Çabık"

# %%
emirhan.name

# %%
class Person():
    name = ""
    age = 0
    gender = ""

    #sınıfların içinde istediğimiz kadar fonk yazabiliriz ve sınıf içindeki fonksiyonlara method denir.

    def __init__(self,nameInput,ageInput,genderInput): #init -> initiliazer demek ilk oluşturmak değerini atamak demektir. def init tanımlarsak eğer bu sınıftan her obje oluşturduğumuzda her bir obje oluşturulurken buradaki fonk çalıştırılacak
        name = nameInput
        gender = genderInput
        age = ageInput

        #def __init__(self) - > self parametresi

# %%
emirhan = Person()

# %%
emirhan = Person("emirhan", 22, "Male")

# %%
type(emirhan)
# Out:
# __main__.Person

# %%
emirhan.name
# Out:
# ''

# %%
emirhan.age
# Out:
# 0

# %%
emirhan.gender
# Out:
# ''

# %%
#istediğimiz neden olmuyor çünkü buradaki self def __init__(self,nameInput,ageInput,genderInput) sınıfın kendisine referans veriyor ve karmaşa olmasın diye oluşturulan bir kelime
# self.name self.gender self.age yapsaydık referans olacaktı ve sınıftan oluşan objenin değerleri değişecekti.

# %%
class Person():
    #Property -> Python'a özgü bir durum bunları tanımlamana gerek kalmaz.
    name = ""
    age = 0
    gender = ""

    #sınıfların içinde istediğimiz kadar fonk yazabiliriz ve sınıf içindeki fonksiyonlara method denir.
    #initializer method
    def __init__(self,name,age,gender): #init -> initiliazer demek ilk oluşturmak değerini atamak demektir. def init tanımlarsak eğer bu sınıftan her obje oluşturduğumuzda her bir obje oluşturulurken buradaki fonk çalıştırılacak
        self.name = name
        self.gender = gender
        self.age = age

        #def __init__(self) - > self parametresi
 #NOT BU KULLANIM ÇOK MANTIKLI KULLANIM DEĞİLDİR !!!

    #method
    def printName(self):
        print(self.name)

# %%
emirhan.name
# Out:
# ''

# %%
emirhan = Person("emirhan", 22, "Male")

# %%
emirhan.name
# Out:
# 'emirhan'

# %%
emirhan.gender
# Out:
# 'Male'

# %%
emirhan.age
# Out:
# 22

# %%
#Method tanımlarken her zaman self ile sınıfın kendisine referans veriyoruz.

# %%
emirhan.name
# Out:
# 'emirhan'

# %%
class Person():
    #Property -> Python'a özgü bir durum bunları tanımlamana gerek kalmaz.
    #name = ""
    #age = 0
    #gender = ""
    job = ""
    def __init__(self,name,age,gender): #init -> initiliazer demek ilk oluşturmak değerini atamak demektir. def init tanımlarsak eğer bu sınıftan her obje oluşturduğumuzda her bir obje oluşturulurken buradaki fonk çalıştırılacak
        self.name = name
        self.gender = gender
        self.age = age
        
    def printName(self):
        print(self.name)

# %%
emirhan.job = "Developer"

# %%
emirhan.job
# Out:
# 'Developer'

# %% [markdown]
# # Sınıf Örnekleri

# %%
class Dog():

    year = 7

    def __init__ (self,age):
        self.age = age

    def humanAge(self):
        return self.age * self.year # self.year -> Dog.year

# %%
myDog = Dog(3)

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21

# %%
class Dog():

    year = 7

    def __init__ (self,age):
        self.age = age
        self.DogHumanAge = age * self.year
        print("Dog Instance")

    def humanAge(self):
        return self.age * self.year

# %%
myDog = Dog(5)
# Out:
# Dog Instance

# %%
myDog.age
# Out:
# 5

# %%
myDog.DogHumanAge
# Out:
# 35

# %%
myDog.humanAge()
# Out:
# 35

# %% [markdown]
# # Inheritance (Kalıtım Almak)

# %%
class Musician():

    def __init__(self,name):
        #property
        self.name = name
        print("Müzisyen Sınıfı")

    def sinestezik(self):
        print("Bu kişi duyduğu seslerin tadını alabiliyor")
    def elestiriyeAcik(self):
        print("Bu kişiler eleştiriye açıktır")

# %%
Emirhan = Musician("Emirhan")
# Out:
# Müzisyen Sınıfı

# %%
emirhan.name
# Out:
# 'emirhan'

# %%
Emirhan.sinestezik()
# Out:
# Bu kişi duyduğu seslerin tadını alabiliyor

# %%
Emirhan.elestiriyeAcik()
# Out:
# Bu kişiler eleştiriye açıktır

# %%
class MusicianPlus(Musician):
    
    def __init__(self,name):
        Musician.__init__(self,name)
        print("Musician Plus")

    def hosgoru(self):
        print("Bu Kişi Hoşgörülüdür")

# %%
Cabik = MusicianPlus("Cabik")
# Out:
# Müzisyen Sınıfı
# Musician Plus

# %%
emirhan.name
# Out:
# 'emirhan'

# %%
Cabik.name ="Cabik Cabikoglu"

# %%
type(Cabik)
# Out:
# __main__.MusicianPlus

# %%
type(Emirhan)
# Out:
# __main__.Musician

# %%
Cabik.hosgoru()
# Out:
# Bu Kişi Hoşgörülüdür

# %%
Emirhan.hosgoru() # İşte burada hata veriyor çünkü biz kalıtım olarak Musician'ı kullandık Musician Plus sınıfında ekstra olarak bir hosgoru sınıfı tanımladık
#Musician sınıfında bu özellik olmadığı için çalışmıyor.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 Emirhan.hosgoru() # İşte burada hata veriyor çünkü biz kalıtım olarak Musician'ı kullandık Musician Plus sınıfında ekstra olarak bir hosgoru sınıfı tanımladık
#       2 #Musician sınıfında bu özellik olmadığı için çalışmıyor.
#
# AttributeError: 'Musician' object has no attribute 'hosgoru'

# %% [markdown]
# # Inheritance (Kalıtım/Miras), programcılığın en sevdiği şey olan "Hazıra Konmak" demektir.
#
# Yine hiç teknik terim kullanmadan, en basit haliyle anlatıyorum:
#
# 🧬 DNA ve Genetik Örneği
# Düşün ki senin baban çok yetenekli bir adam.
#
# Göz Rengi: Kahverengi
#
# Yetenek: Araba sürebiliyor
#
# Boy: 1.80
#
# Sen doğduğunda, oturup "Benim gözüm kahverengi olsun, boyum uzun olsun" diye sıfırdan uğraşmazsın. Bu özellikleri babandan direkt (Miras) alırsın. Sen doğduğun an, zaten araba sürebilme potansiyeline ve kahverengi gözlere sahipsin.
#
# Ekstra olarak sen kendine "İngilizce konuşmak" gibi yeni özellikler ekleyebilirsin ama temel özellikleri babadan kopyaladın bile.

# %% [markdown]
# # Polymorphism (Aynı isimle farklı işlevi yapmak)

# %%
class Banana():

    def __init__(self,name):
        self.name = name

    def infos(self):
        return f"100 calorie {self.name}"
        
class Apple():

    def __init__(self,name):
        self.name = name

    def infos(self):
        return f"150 calorie {self.name}"

# %%
banana_object = Banana("banana")

# %%
apple_object = Apple("apple")

# %%
banana_object.infos()
# Out:
# '100 calorie banana'

# %%
apple_object.infos()
# Out:
# '150 calorie apple'

# %%
fruitList = [banana_object, apple_object]

# %%
for fruit in fruitList:
    print(fruit.infos())
# Out:
# 100 calorie banana
# 150 calorie apple

# %% [markdown]
# # Polymorphism (Çok Biçimlilik) aslında "Tek bir emir ver, herkes kendine göre anlasın" demektir.
#
# Günlük Hayattan Örnek: "Oynat" Tuşu
# Hayal et; elinde sihirli bir kumanda var ve üzerinde sadece "ÇAL" (Play) tuşu var.
#
# Karşında da üç tane müzisyen var:
#
# Gitarist
#
# Piyanist
#
# Davulcu
#
# Sen kumandadaki "ÇAL" tuşuna basıyorsun (Bu senin kodundaki .infos() komutu).
#
# Gitarist bunu görünce ne yapar? Tellerine vurur.
#
# Piyanist bunu görünce ne yapar? Tuşlara basar.
#
# Davulcu bunu görünce ne yapar? Bagetle vurur.
#
# Bak dikkat et; sen hepsine aynı emri verdin ("ÇAL"). Ama hepsi kendi yapısına uygun olan farklı bir hareketi yaptı.
#
# İşte Polymorphism budur! Sen "Gitarist sen tel çek, Piyanist sen tuşa bas" diye tek tek uğraşmazsın. Hepsine "ÇAL" dersin, gerisini onlar halleder.

# %% [markdown]
# # Encapsulation (Hapsetmek)

# %%
class Phone():

    def __init__(self,name,price):
        self.name = name
        self.__price = price #Encapsulation budur -> Sadece bunun içinden ulaşabiliriz buna.  (__)

    def info(self):
        print(f"{self.name} price is: {self.__price}")

    def changePrice(self,price):
        self.__price = price

# %%
iphone = Phone("iPhone 14", 500)

# %%
iphone.info()
# Out:
# iPhone 14 price is: 500

# %%
iphone.price = 400

# %%
iphone.info()
# Out:
# iPhone 14 price is: 500

# %%
iphone.changePrice(300)

# %%
iphone.info()
# Out:
# iPhone 14 price is: 300

# %% [markdown]
# # Encapsulation (Kapsülleme), en kısa özetiyle "Eline, beline, diline sahip çık!" prensibidir. Ya da daha teknik olmayan tabiriyle: "Benim içimdeki kablolara dokunma, sadece düğmelere bas!" demektir.
#
# Yine hiç kod dünyasına girmeden, en basit haliyle anlatıyorum:
#
# ☕ Kahve Makinesi Örneği
# Evinde bir kapsül kahve makinesi olduğunu düşün.
#
# Sen ne yapabilirsin? (Public - Halka Açık Kısım)
#
# Düğmeye basabilirsin.
#
# Su haznesine su koyabilirsin.
#
# Kapsülü yerleştirebilirsin.
#
# Sen ne YAPAMAZSIN? (Private - Gizli Kısım)
#
# Makinenin içindeki ısıtıcı rezistansa parmak atamazsın. (Yanarsın!)
#
# Pompanın basınç ayarını tornavidayla kurcalayamazsın. (Makineyi bozarsın!)
#
# Suyun kaynama derecesini anakart üzerinden değiştiremezsin.
#
# İşte o makinenin şık plastik dış kaplaması bir Kapsül (Encapsulation)'dür. Seni makinenin tehlikeli iç aksamından korur, makineyi de senin "acemi" parmaklarından korur.

# %% [markdown]
# # Abstraction (Soyutlama)

# %%
from abc import ABC, abstractmethod

# %%
class Car(ABC):
    @abstractmethod
    def maxSpeed(self):
        pass

# %%
#myCar = Car()

# %%
class Tesla(Car):

    def maxSpeed(self):
        print("200km")

# %%
tesla = Tesla()

# %%
tesla.maxSpeed()
# Out:
# 200km

# %%
class Mercedes(Car):

    def maxSpeed(self):
        print("250km")

# %%
mercedes = Mercedes()

# %%
mercedes.maxSpeed()
# Out:
# 250km

# %% [markdown]
# # Abstraction (Soyutlama), en basit haliyle "Detaylarda boğulma, sadece ne işe yaradığına bak!" demektir.
#
# Yine teknik terim kullanmadan, aptala anlatır gibi anlatıyorum:
#
# 🚗 Araba Kullanma Örneği
# Sen arabaya bindiğinde ne yaparsın?
#
# Gaza basarsın -> Araba gider.
#
# Frene basarsın -> Araba durur.
#
# Direksiyonu çevirirsin -> Araba döner.
#
# Peki gaza bastığında kaputun altında neler olduğunu biliyor musun?
#
# Hangi pistonun kaç milisaniye açıldığını?
#
# Benzinin hava ile hangi oranda karıştığını?
#
# Ateşleme bujisinin kaç volt elektrik çaktığını?
#
# BİLMİYORSUN! BİLMENE DE GEREK YOK!
#
# Eğer araba sürmek için motorun içindeki bütün mühendisliği bilmek zorunda kalsaydın, dünyada kimse ehliyet alamazdı.
#
# İşte arabanın pedalları ve direksiyonu senin için bir Abstraction (Soyutlama)'dır. Karmaşık motor detaylarını senden gizler ve sana sadece basit bir arayüz (pedal) sunar.

# %%
class Fruit():

    def __init__(self,name,calories):
        self.name = name
        self.calories = calories

    def __str__(self):
        return f"{self.name}: {self.calories} colories"

    def __len__(self):
        return self.calories

# %%
myFruit = Fruit("banana",150)

# %%
myFruit.calories
# Out:
# 150

# %%
myFruit.name
# Out:
# 'banana'

# %%
print(myFruit)
# Out:
# banana: 150 colories

# %%
len(myFruit)
# Out:
# 150

# %%
class Train():

    def __init__(self,name):
        self.name = name

    def __getitem__(self,key):
        if key == "a":
            return self.name
        else:
            return "Not Found"

# %%
myTrain = Train("Maglev")

# %%
myTrain["a"]
# Out:
# 'Maglev'

# %%
myTrain["b"]
# Out:
# 'Not Found'
